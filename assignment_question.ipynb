# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
# Your code here
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
# Your code here
name  = input("Enter your name")
print("My name is :", name)
# Out:
# My name is : Jagroop

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
# Your code here
num = int(input("Enter a number:"))
if num ==0:
    print("zero")
elif num <0:
    print("negative")
else:
    print("positive")
# Out:
# positive

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
# Your code here
import math
num1,num2,num3 = 2,3,1
if num1 > num2 and num1 > num3:
    print("number 1 is max",num1)
if num2 > num1 and num2 > num3:
    print("number 2 is max",num2)
else:
    print("number 3 is max",num3)
# Out:
# number 2 is max 3

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
# Your code here
num =5 
fact = 1
for i in range(num,1,-1):
    fact= fact*i
print(f"Factorial of {num} is : {fact}")
# Out:
# Factorial of 5 is : 120

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
# Your code here
name = "Jagroop"
age = 22
height = 6.1
role = "Software Engineer"
have_degree = True

print(f"{have_degree} datatype is {type(have_degree)}")
# Out:
# True datatype is <class 'bool'>

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
# Your code here
num1 , num2 = 1,2

num1, num2 = num2, num1
print(num1, num2)
# Out:
# 2 1

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
# Your code here
celcius = 32
farenheit = (celcius * 9/5) + 32 
print(farenheit)
# Out:
# 89.6

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
# Your code here
str1 = "Hello "
str2 ="World !"
print(str1+str2)
# Out:
# Hello World !

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
# Your code here
age = 20

print(f"Is age is of type int: {isinstance(age,int)}")
print(f"Is age is of type string: {isinstance(age,str)}")
# Out:
# Is age is of type int: True
# Is age is of type string: False

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
# Your code here
a,b = 2,20
print("Sum",a+b)
print("Subtraction",a-b)
print("Multiplication",a*b)
print("Division",a/b)
print("Division",a//b)
# Out:
# Sum 22
# Subtraction -18
# Multiplication 40
# Division 0.1
# Division 0

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
# Your code here
a,b = 2,2 
print(a==b)
print(a!=b)
print(a>b)
print(a<b)
# Out:
# True
# False
# False
# False

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
# Your code here
a,b = True, False
print(a and b)
print(a or b)
print(a and not b)
# Out:
# False
# True
# True

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
# Your code here
number = 5
print(number*number)
# Out:
# 25

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
# Your code here
num = 1011

if num%2 ==0:
    print("even")
else:
    print("odd")
# Out:
# odd

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
# Your code here
n = 5
sum_ =0
for i in range(1,n+1):
    sum_ +=i
print(sum_)
# Out:
# 15

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
# Your code here
year = 2028
if (year % 400 == 0):
    print(True)
elif (year % 100 == 0):
    print(False)
elif (year % 4 == 0):
    print(True)
else:
    print(False)
# Out:
# True

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
# Your code here
string =" My name is Jagroop"
str_list = list(string)
str_list.reverse()
"".join(str_list)
# Out:
# 'poorgaJ si eman yM '

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
# Your code here
string = "WOWE"
str_list = list(string)
str_list.reverse()
reversed_list = "".join(str_list)
print("Palindrome" if string == reversed_list else "Not Palindrome")
# Out:
# Not Palindrome

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
# Your code here
number = [7,6,4,3,2,1]
number.sort()
print(number)
# Out:
# [1, 2, 3, 4, 6, 7]
